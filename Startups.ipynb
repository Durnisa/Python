# %% [markdown]
# <a href="https://colab.research.google.com/github/Durnisa/Python/blob/main/Startups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# See the first 10 entries
df = pd.read_csv("50_Startups.csv")
Startup =pd.read_csv("50_Startups.csv")
df.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42         NaN  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
# What is the number of observations in the dataset
Startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            45 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# What is the number of columns in the dataset
Startup.shape[1]
# Out:
# 5

# %%
# Print the name of all the columns
Startup.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
# How is the dataset indexed
Startup.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Which was the Max Profit
c = Startup.groupby('State')
c = c.sum()
c = c.sort_values(['Profit'], ascending=False)
c.head(1)
# Out:
#            R&D Spend  Administration  Marketing Spend      Profit
# State
# New York  1295316.06       2066239.0       3490882.27  1933859.59

# %%
 # Sum Profit group by State
 c = Startup.groupby('State')
c = c.sum()
c = c.sort_values(['Profit'], ascending=False)
c.head()
# Out:
#              R&D Spend  Administration  Marketing Spend      Profit
# State
# New York    1295316.06      2066239.00       3490882.27  1933859.59
# California  1055110.51      1865980.56       2906166.38  1633879.11
# Florida      992069.89      1643258.99       3147212.64  1491295.58
